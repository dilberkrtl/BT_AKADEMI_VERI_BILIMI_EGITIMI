# %%
# Importing Libraries

import requests
from bs4 import BeautifulSoup

# %% [markdown]
# requests:
# This library is used to make HTTP requests. It allows you to send a request to a web page and get data from that page.
#
# BeautifulSoup:
# This library is used to parse documents such as HTML and XML. It allows you to extract the raw HTML code from a web page by putting it into a meaningful structure.

# %%
# Pull Data (Send HTTP Request Request to Web Page)

# URL of the web page
url = "https://www.trendyol.com/damat/ds-damat-soft-cotton-2-li-atlet-beyaz-p-838421125/yorumlar"

# Sending an HTTP request
response = requests.get(url)

# Printing page content
response.text
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File c:\Users\MSI-NB\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# ...

# %% [markdown]
# In the url variable, we write the address of the web page from which we want to retrieve data.
#
# The requests.get(url) command sends an HTTP GET request to this URL. That is, we request the specified web page. This makes a request that returns the content of the web page to us. The response is stored in the response variable.

# %%
import requests

cookies = {
    'hvtb': '1',
    'platform': 'web',
    'pid': 'vwTaKcafeF',
    '_ym_uid': '172167798578039972',
    '_ym_d': '1721677985',
    'WebAbTesting': 'A_43-B_80-C_40-D_84-E_28-F_23-G_57-H_80-I_45-J_82-K_12-L_99-M_13-N_62-O_35-P_26-Q_82-R_2-S_97-T_73-U_97-V_49-W_98-X_24-Y_47-Z_8',
    '_fbp': 'fb.1.1721678017116.147640412403665541',
    'OptanonAlertBoxClosed': '2024-07-22T20:29:04.293Z',
    'COOKIE_TY.UserAlreadyLogged': 'x=1&pp=gmzZ7qH19gWXfdueTp3NLhm5Eyg=&tx=gmzZ7qH19gWXfdueTp3NLhm5Eyg=&',
    'token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....7oj1XJATXJrm5hMGVaIOXgWfBkrYOoDqAy6Wkg7d-3w',
    'UserInfo': '%7B%22Gender%22%3A%221%22%7D',
    'UserSegments': '%5B%7B%22id%22%3A%22410750067%22%2C%22tag%22%3A%221%22%7D%5D',
    'COOKIE_TY.Entrance': 'x=34870869&pp=wT/ZuZNW92fcNw8tyqDCrgNiitM=&tx=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....7oj1XJATXJrm5hMGVaIOXgWfBkrYOoDqAy6Wkg7d-3w&FirstName=Mehmet&LastName=Ali%20Bayram&Gender=1&Phone=551%2A%2A%2A%2A%2A10&UserName=Mehmet%20Ali%20Bayram&VisitorType=Buyer&EmailSha255Hashed=f670a508cc5083ca6addef58a5fdec52bb7740e28f20f42528eea2aebc54780c&EmailMd5Hashed=0557be167d2c6a2998c3dd504bff30b9&UserTypeStatus=Member&UserId=34870869&Email=malibayram20%40gmail.com&RefreshToken=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE3MjU5MDQ1MzEsInN1YiI6MX0._K5AAOgv0eD3ywx3JN9IoWsJ7hTF1UelnXdgs4m8Thk&HasDeviceToken=False&HasSavedCreditCard=False&MarketingEmailsAuthorized=False',
    '_hjSessionUser_2713408': 'eyJpZCI6IjRkZmFlNzk3LWE0MjUtNTNjNS1hOWNjLTcwOWE3YWEwZjk1MiIsImNyZWF0ZWQiOjE3MjU5NjU1MDg0OTIsImV4aXN0aW5nIjp0cnVlfQ==',
    '_gcl_aw': 'GCL.1727425857.Cj0KCQjwr9m3BhDHARIsANut04ZMF7MGrNF1fl0BlLpDcPyDypXnL09QNeRMF4bpsuWfHyiO94lspqYaAsGTEALw_wcB',
    '_gcl_gs': '2.1.k4$i1727425856',
    '_gac_UA-13174585-1': '1.1727426005.Cj0KCQjwr9m3BhDHARIsANut04ZMF7MGrNF1fl0BlLpDcPyDypXnL09QNeRMF4bpsuWfHyiO94lspqYaAsGTEALw_wcB',
    '_ga_8F2NHTRF7T': 'GS1.1.1727427188.6.0.1727427188.60.0.0',
    '_ga_FZ7435S7BY': 'GS1.1.1727688022.12.1.1727688058.24.0.0',
    '_gcl_au': '1.1.1412789174.1729523132',
    'pfx_postclick': 'gelirortaklari',
    'ForceUpdateSearchAbDecider': 'forced',
    'msearchAb': 'ABSearchFETestV1_A-ABSuggestionLC_A-ABSuggestionPS_A',
    'recoAb': 'ABRecoBETestV1_A-ABRecoFirstTest_A',
    'FirstSession': '0',
    '_gid': 'GA1.2.1157116357.1730396080',
    '_ym_isad': '2',
    'COOKIE_UserTypeStatus': 'x=Member&pp=GgWd3DV74ysES105NNvWK/oeNlU=&tx=GgWd3DV74ysES105NNvWK/oeNlU=&toBeInfluencer=False',
    'VisitorTypeStatus': 'Buyer',
    '_ga_1': 'GS1.1.1730396082.37.1.1730396103.0.0.1233215529',
    '_ga': 'GA1.1.513227217.1721678016',
    'OptanonConsent': 'isGpcEnabled=0&datestamp=Thu+Oct+31+2024+20%3A35%3A03+GMT%2B0300+(GMT%2B03%3A00)&version=6.30.0&isIABGlobal=false&hosts=&genVendors=V77%3A0%2CV67%3A0%2CV79%3A0%2CV71%3A0%2CV69%3A0%2CV7%3A0%2CV5%3A0%2CV9%3A0%2CV1%3A0%2CV70%3A0%2CV3%3A0%2CV68%3A0%2CV78%3A0%2CV17%3A0%2CV76%3A0%2CV80%3A0%2CV16%3A0%2CV72%3A0%2CV10%3A0%2CV40%3A0%2C&consentId=56f51225-601c-4b5f-8114-751f37fb5a19&interactionCount=2&landingPath=NotLandingPage&groups=C0002%3A1%2CC0004%3A1%2CC0003%3A1%2CC0001%3A1%2CC0007%3A1%2CC0009%3A1&AwaitingReconsent=false&geolocation=TR%3B06',
    'VisitCount': '57',
    'sid': 'iGlyxYCT9T',
    'AbTesting': 'SFWDBSR_B-SFWDRS_A-SFWDSAOF_A-SFWDSFAG_B-SFWDTKV2_A-STSBuynow_B-WCAATestv1_A-WCBsRmndv2_B-WCBsSvShowTimer_B-ZZTEST1_A%7C1730401486',
    '__cf_bm': 'q4WGhSuNYcGkh84Ki62.LrKGbpEpUrBeCEH3ypnoOXI-1730400033-1.0.1.1-FLYmgX9LSaVHI0GjIrphr.hAPaTCUgqAoakXyzNqr4KPfb3IYGCJiZHKWwMplrVVHSTUA169iZlVdDCBYXl5cg',
    '__cflb': '04dToYCH9RsdhPpttacYW22gpq3mLXZNE3LQSXPvwo',
    '_cfuvid': '5iDC_nwmwvFakJQ_OTMkUlWPWiqbaeNhgEa.3K01ZXM-1730400033794-0.0.1.1-604800000',
}

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'en-US,en;q=0.
',
    'sec-ch-ua-mobile': '?1',
    'sec-ch-ua-platform': '"Android"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Mobile Safari/537.36',
}

response = requests.get(
    'https://apigw.trendyol.com/discovery-web-websfxsocialreviewrating-santral/product-reviews-detailed?&sellerId=104901&contentId=838421125&order=DESC&orderBy=Score&rates=2&rates=5&rates=4&channelId=1',
    cookies=cookies,
    headers=headers,
)

# %%
response.text
# Out:
# '{"isSuccess":true,"statusCode":200,"result":{"contentSummary":{"productSizes":[{"name":"L","count":37},{"name":"XL","count":19},{"name":"M","count":17},{"name":"2XL","count":9}],"ratingCounts":[{"rate":5,"count":112,"commentCount":71},{"rate":4,"count":16,"commentCount":9},{"rate":3,"count":3,"commentCount":1},{"rate":2,"count":3,"commentCount":3},{"rate":1,"count":6,"commentCount":4}],"tags":[{"name":"tümü","count":83},{"name":"kalite","count":1},{"name":"kumaş kalitesi","count":2},{"name":"beden bilgisi","count":1},{"name":"kalıp / boyut / ölçü","count":1},{"name":"yumuşacık tavsiye","count":1},{"name":"çeyiz","count":1}],"userCommentExist":false,"averageRating":4.6,"totalCommentCount":88,"totalRatingCount":140,"isSearchable":false,"description":"Hizmet ve ürün kalitesi sebebiyle işbirliğimizi sonlandırdığımız satıcıların ürünlerini satıştan kaldırdığımız için, size daha doğru deneyim sunabilmek adına, bu satıcılardan yapılan alışverişlerdeki değerlendirmeleri ürün puanına dahil e
# ...

# %%
import json

data = json.loads(response.text)

data
# Out:
# {'isSuccess': True,
#  'statusCode': 200,
#  'result': {'contentSummary': {'productSizes': [{'name': 'L', 'count': 37},
#     {'name': 'XL', 'count': 19},
#     {'name': 'M', 'count': 17},
#     {'name': '2XL', 'count': 9}],
#    'ratingCounts': [{'rate': 5, 'count': 112, 'commentCount': 71},
#     {'rate': 4, 'count': 16, 'commentCount': 9},
#     {'rate': 3, 'count': 3, 'commentCount': 1},
#     {'rate': 2, 'count': 3, 'commentCount': 3},
#     {'rate': 1, 'count': 6, 'commentCount': 4}],
#    'tags': [{'name': 'tümü', 'count': 83},
#     {'name': 'kalite', 'count': 1},
#     {'name': 'kumaş kalitesi', 'count': 2},
#     {'name': 'beden bilgisi', 'count': 1},
#     {'name': 'kalıp / boyut / ölçü', 'count': 1},
#     {'name': 'yumuşacık tavsiye', 'count': 1},
#     {'name': 'çeyiz', 'count': 1}],
#    'userCommentExist': False,
#    'averageRating': 4.6,
#    'totalCommentCount': 88,
#    'totalRatingCount': 140,
#    'isSearchable': False,
# ...

# %%
# save to json file utf-8
with open("data.json", "w", encoding="utf-8") as f:
    json.dump(data, f, ensure_ascii=False)

# %%
data['result']['productReviews']['content'][4]
# Out:
# {'isElite': True,
#  'isInfluencer': False,
#  'commentDateISOtype': '24 Kasım 2024',
#  'userFullName': 'B** B** G**',
#  'id': 445542724,
#  'rate': 5,
#  'commentTitle': '',
#  'comment': 'Çok kaliteli bir ürün tavsiye ederim',
#  'trusted': True,
#  'lastModifiedDate': '24 Kasım 2024',
#  'sellerName': "THERMOFORM - D'S",
#  'reviewLikeCount': 0,
#  'userLiked': False,
#  'productSize': '2XL',
#  'productAttributes': {'height': '165', 'weight': '65'},
#  'productVariant': {'attribute': 'size', 'value': '2XL'}}

# %%
elitscount = 0
for yorum in data['result']['productReviews']['content']:
  if yorum['isInfluencer']:
    elitscount += 1

elitscount
# Out:
# 0
