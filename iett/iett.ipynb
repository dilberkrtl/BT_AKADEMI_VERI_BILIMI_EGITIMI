# %%
# Araç ve kütüphaneleri yükleme

import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
cookies = {
    '_gid': 'GA1.2.630976569.1730740169',
    '_ga': 'GA1.1.906449395.1730392928',
    '_ga_XW7CBTH4XZ': 'GS1.2.1730740168.4.1.1730740181.0.0.0',
    '_ga_DTXKBRBZED': 'GS1.1.1730740168.5.1.1730740628.0.0.0',
    'IE31a9bbc7':'313ce3296e80af731ece9281ec95949ad98420eef7f2b0825b9636b87acd2ddba39f7e257c5b0eleda15106cc2f7cbc5fa80cb9e66',
}

headers = {
    'Accept': 'text/html, * / *; q=0.01',
    'Accept-Language': 'en-US, en; q=0. 9, tr; q=0.8',
    'Connection': 'keep-alive',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
# Cookie': '_gid=GA1.2.630976569, 1730740169; _ ga=GA1.1.906449395.1730392928; _ ga_XW7CBTH4XZ=GS1.2.1730740168.4.1.1730740181.0.0.
    'Origin': 'https://iett.istanbul',
    'Referer': 'https://iett.istanbul/announcement/Index',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same origin',
    'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Mob',
    'X-Requested-With': 'XMLHttpRequest',
    'sec-ch-ua': '"Chromium"; v="130", "Google Chrome"; v="130", "Not?A_Brand" ; v="99"',
    'sec-ch-ua-mobile': '71',
    'sec-ch-ua-platform': '"Android"',
}

data = {
    'Page': '212',
    'Ingid': '1',
}

# %%
response = requests. get('https://iett.istanbul/tr/Announcement', cookies=cookies, headers=headers, data=data)

# %%
response.text
# Out:
# "<html><head><title>Request Rejected</title></head><body>The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 11130123881254058252<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"

# %%
response = requests. post('https://iett.istanbul/tr/Announcement', cookies=cookies, headers=headers, data=data)

# %%
response.text
# Out:
# "<html><head><title>Request Rejected</title></head><body>The requested URL was rejected. Please consult with your administrator.<br><br>Your support ID is: 11130123881254058404<br><br><a href='javascript:history.back();'>[Go Back]</a></body></html>"
