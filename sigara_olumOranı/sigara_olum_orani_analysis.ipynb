# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\msi-nb\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\msi-nb\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\msi-nb\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\msi-nb\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\msi-nb\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\msi-nb\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Gerekli kütüphaneleri import etme
import pandas as pd

# %%
# Veriyi yükleme
sigara_verisi = pd.read_csv("sigara_olumOranı_dataset.csv")
sigara_verisi
# Out:
#      Yıl  Sigara İçen Kişi Sayısı (milyon)  \
# 0   2000                             1.638
# 1   2001                             1.643
# 2   2002                             1.648
# 3   2003                             1.653
# 4   2004                             1.658
# 5   2005                             1.672
# 6   2006                             1.677
# 7   2007                             1.682
# 8   2008                             1.687
# 9   2009                             1.692
# 10  2010                             1.697
# 11  2011                             1.701
# 12  2012                             1.705
# 13  2013                             1.709
# 14  2014                             1.713
# 15  2015                             1.707
# 16  2016                             1.719
# 17  2017                             1.723
# 18  2018                             1.718
# 19  2019                             1.671
# 20  2020                             1.655
# 21  2021                             1.638
# 22  2022                             1.623
#
#     Sigaradan Ölen Kişi Sayısı (milyon)  Toplam Ölen Kişi Sayısı (milyon)
# 0                                   4.9                              54.8
# 1                                   5.0                              55.3
# 2                                   5.1                              56.0
# 3                                   5.2                              56.6
# 4                                   5.3                              57.2
# 5                                   5.4                              58.8
# 6                                   5.5                              59.4
# 7                                   5.6                              60.0
# 8                                   5.7                              60.6
# 9                                   5.8                              61.2
# 10                                  6.2                              60.8
# 11                                  6.3                              61.3
# 12                                  6.4                              62.0
# 13                                  6.5                              62.4
# 14                                  6.6                              62.8
# 15                                  7.0                              57.4
# 16                                  6.8                              63.4
# 17                                  7.0                              57.4
# 18                                  7.1                              58.2
# 19                                  7.7                              59.3
# 20                                  8.0                              61.0
# 21                                  8.2                              59.5
# 22                                  8.3                              60.2

# %%
# Veriyi ayrıntılı kontrol etme
sigara_verisi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 4 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Yıl                                  23 non-null     int64
#  1   Sigara İçen Kişi Sayısı (milyon)     23 non-null     float64
#  2   Sigaradan Ölen Kişi Sayısı (milyon)  23 non-null     float64
#  3   Toplam Ölen Kişi Sayısı (milyon)     23 non-null     float64
# dtypes: float64(3), int64(1)
# memory usage: 868.0 bytes

# %%
# Veriyi kontrol etme - ilk 5 satırı görmme
sigara_verisi.head()
# Out:
#     Yıl  Sigara İçen Kişi Sayısı (milyon)  \
# 0  2000                             1.638
# 1  2001                             1.643
# 2  2002                             1.648
# 3  2003                             1.653
# 4  2004                             1.658
#
#    Sigaradan Ölen Kişi Sayısı (milyon)  Toplam Ölen Kişi Sayısı (milyon)
# 0                                  4.9                              54.8
# 1                                  5.0                              55.3
# 2                                  5.1                              56.0
# 3                                  5.2                              56.6
# 4                                  5.3                              57.2

# %%
# Gerekli kütüphaneleri import etme
import matplotlib.pyplot as plt

# %%
# Sigara İçen Kişi Sayısı (milyon) - Yıl bazında grafiği
plt.plot(sigara_verisi["Yıl"], sigara_verisi["Sigara İçen Kişi Sayısı (milyon)"])
plt.xlabel('Yıl')
plt.ylabel('Sigara İçen Kişi Sayısı (milyon)')
plt.title('Yıl-Sigara İçen Kişi Sayısı')
plt.show()

# %%
# Sigaradan Ölen Kişi Sayısı (milyon) - Yıl bazında grafiği
plt.plot(sigara_verisi["Yıl"], sigara_verisi["Sigaradan Ölen Kişi Sayısı (milyon)"])
plt.xlabel('Yıl')
plt.ylabel('Sigaradan Ölen Kişi Sayısı (milyon)')
plt.title('Yıl-Sigaradan Ölen Kişi Sayısı')
plt.show()

# %%
# Toplam Ölen Kişi Sayısı (milyon) - Yıl bazında grafiği
plt.plot(sigara_verisi["Yıl"], sigara_verisi["Toplam Ölen Kişi Sayısı (milyon)"])
plt.xlabel('Yıl')
plt.ylabel('Toplam Ölen Kişi Sayısı (milyon)')
plt.title('Yıl-Toplam Ölen Kişi Sayısı')
plt.show()

# %%
# Yıl-Sigaradan Ölen Kişi Sayısı Scatter Grafiği
plt.scatter(sigara_verisi["Yıl"], sigara_verisi["Sigaradan Ölen Kişi Sayısı (milyon)"], color="red")
plt.xlabel('Yıl')
plt.ylabel('Sigaradan Ölen Kişi Sayısı (milyon)')
plt.title('Yıl-Sigaradan Ölen Kişi Sayısı')
plt.show()

# %%
# Yeni bir sütun ekleyelim: Sigara İçenlerin Ölüm Oranı
#sigara_verisi["Sigara İçenlerin Ölüm Oranı"] = (sigara_verisi["Sigaradan Ölen Kişi Sayısı (milyon)"] / sigara_verisi["Toplam Ölen Kişi Sayısı (milyon)"]) * 100
sigara_verisi["Sigara İçenlerin Ölüm Oranı"] = ((sigara_verisi["Sigaradan Ölen Kişi Sayısı (milyon)"] / sigara_verisi["Toplam Ölen Kişi Sayısı (milyon)"])*100).apply(lambda x: f"% {x:.2f}")
sigara_verisi.head()
# Out:
#     Yıl  Sigara İçen Kişi Sayısı (milyon)  \
# 0  2000                             1.638
# 1  2001                             1.643
# 2  2002                             1.648
# 3  2003                             1.653
# 4  2004                             1.658
#
#    Sigaradan Ölen Kişi Sayısı (milyon)  Toplam Ölen Kişi Sayısı (milyon)  \
# 0                                  4.9                              54.8
# 1                                  5.0                              55.3
# 2                                  5.1                              56.0
# 3                                  5.2                              56.6
# 4                                  5.3                              57.2
#
#   Sigara İçenlerin Ölüm Oranı
# 0                      % 8.94
# 1                      % 9.04
# 2                      % 9.11
# 3                      % 9.19
# 4                      % 9.27

# %%
# Sigara İçenlerin Ölüm Oranı - Toplam Ölen Kişi Sayısı Scatter Grafiği
plt.scatter(sigara_verisi["Toplam Ölen Kişi Sayısı (milyon)"], sigara_verisi["Sigara İçenlerin Ölüm Oranı"], color="purple")
plt.xlabel('Toplam Ölen Kişi Sayısı (milyon)')
plt.ylabel('Sigara İçenlerin Ölüm Oranı')
plt.title('Sigara İçenlerin Ölüm Oranı - Toplam Ölen Kişi Sayısı')
plt.show()

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\msi-nb\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\msi-nb\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\msi-nb\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\msi-nb\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\msi-nb\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\msi-nb\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Gerekli kütüphaneleri import etme
import pandas as pd

# %%
# Veriyi yükleme
sigara_verisi = pd.read_csv("sigara_olumOranı_dataset.csv")
sigara_verisi
# Out:
#      Yıl  Sigara İçen Kişi Sayısı (milyon)  \
# 0   2000                             1.638
# 1   2001                             1.643
# 2   2002                             1.648
# 3   2003                             1.653
# 4   2004                             1.658
# 5   2005                             1.672
# 6   2006                             1.677
# 7   2007                             1.682
# 8   2008                             1.687
# 9   2009                             1.692
# 10  2010                             1.697
# 11  2011                             1.701
# 12  2012                             1.705
# 13  2013                             1.709
# 14  2014                             1.713
# 15  2015                             1.707
# 16  2016                             1.719
# 17  2017                             1.723
# 18  2018                             1.718
# 19  2019                             1.671
# 20  2020                             1.655
# 21  2021                             1.638
# 22  2022                             1.623
#
#     Sigaradan Ölen Kişi Sayısı (milyon)  Toplam Ölen Kişi Sayısı (milyon)
# 0                                   4.9                              54.8
# 1                                   5.0                              55.3
# 2                                   5.1                              56.0
# 3                                   5.2                              56.6
# 4                                   5.3                              57.2
# 5                                   5.4                              58.8
# 6                                   5.5                              59.4
# 7                                   5.6                              60.0
# 8                                   5.7                              60.6
# 9                                   5.8                              61.2
# 10                                  6.2                              60.8
# 11                                  6.3                              61.3
# 12                                  6.4                              62.0
# 13                                  6.5                              62.4
# 14                                  6.6                              62.8
# 15                                  7.0                              57.4
# 16                                  6.8                              63.4
# 17                                  7.0                              57.4
# 18                                  7.1                              58.2
# 19                                  7.7                              59.3
# 20                                  8.0                              61.0
# 21                                  8.2                              59.5
# 22                                  8.3                              60.2

# %%
# Veriyi ayrıntılı kontrol etme
sigara_verisi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 4 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Yıl                                  23 non-null     int64
#  1   Sigara İçen Kişi Sayısı (milyon)     23 non-null     float64
#  2   Sigaradan Ölen Kişi Sayısı (milyon)  23 non-null     float64
#  3   Toplam Ölen Kişi Sayısı (milyon)     23 non-null     float64
# dtypes: float64(3), int64(1)
# memory usage: 868.0 bytes

# %%
# Veriyi kontrol etme - ilk 5 satırı görmme
sigara_verisi.head()
# Out:
#     Yıl  Sigara İçen Kişi Sayısı (milyon)  \
# 0  2000                             1.638
# 1  2001                             1.643
# 2  2002                             1.648
# 3  2003                             1.653
# 4  2004                             1.658
#
#    Sigaradan Ölen Kişi Sayısı (milyon)  Toplam Ölen Kişi Sayısı (milyon)
# 0                                  4.9                              54.8
# 1                                  5.0                              55.3
# 2                                  5.1                              56.0
# 3                                  5.2                              56.6
# 4                                  5.3                              57.2

# %%
# Gerekli kütüphaneleri import etme
import matplotlib.pyplot as plt

# %%
# Sigara İçen Kişi Sayısı (milyon) - Yıl bazında grafiği
plt.plot(sigara_verisi["Yıl"], sigara_verisi["Sigara İçen Kişi Sayısı (milyon)"])
plt.xlabel('Yıl')
plt.ylabel('Sigara İçen Kişi Sayısı (milyon)')
plt.title('Yıl-Sigara İçen Kişi Sayısı')
plt.show()

# %%
# Sigaradan Ölen Kişi Sayısı (milyon) - Yıl bazında grafiği
plt.plot(sigara_verisi["Yıl"], sigara_verisi["Sigaradan Ölen Kişi Sayısı (milyon)"])
plt.xlabel('Yıl')
plt.ylabel('Sigaradan Ölen Kişi Sayısı (milyon)')
plt.title('Yıl-Sigaradan Ölen Kişi Sayısı')
plt.show()

# %%
# Toplam Ölen Kişi Sayısı (milyon) - Yıl bazında grafiği
plt.plot(sigara_verisi["Yıl"], sigara_verisi["Toplam Ölen Kişi Sayısı (milyon)"])
plt.xlabel('Yıl')
plt.ylabel('Toplam Ölen Kişi Sayısı (milyon)')
plt.title('Yıl-Toplam Ölen Kişi Sayısı')
plt.show()

# %%
# Yıl-Sigaradan Ölen Kişi Sayısı Scatter Grafiği
plt.scatter(sigara_verisi["Yıl"], sigara_verisi["Sigaradan Ölen Kişi Sayısı (milyon)"], color="red")
plt.xlabel('Yıl')
plt.ylabel('Sigaradan Ölen Kişi Sayısı (milyon)')
plt.title('Yıl-Sigaradan Ölen Kişi Sayısı')
plt.show()

# %%
# Yeni bir sütun ekleyelim: Sigara İçenlerin Ölüm Oranı
#sigara_verisi["Sigara İçenlerin Ölüm Oranı"] = (sigara_verisi["Sigaradan Ölen Kişi Sayısı (milyon)"] / sigara_verisi["Toplam Ölen Kişi Sayısı (milyon)"]) * 100
sigara_verisi["Sigara İçenlerin Ölüm Oranı"] = ((sigara_verisi["Sigaradan Ölen Kişi Sayısı (milyon)"] / sigara_verisi["Toplam Ölen Kişi Sayısı (milyon)"])*100).apply(lambda x: f"% {x:.2f}")
sigara_verisi.head()
# Out:
#     Yıl  Sigara İçen Kişi Sayısı (milyon)  \
# 0  2000                             1.638
# 1  2001                             1.643
# 2  2002                             1.648
# 3  2003                             1.653
# 4  2004                             1.658
#
#    Sigaradan Ölen Kişi Sayısı (milyon)  Toplam Ölen Kişi Sayısı (milyon)  \
# 0                                  4.9                              54.8
# 1                                  5.0                              55.3
# 2                                  5.1                              56.0
# 3                                  5.2                              56.6
# 4                                  5.3                              57.2
#
#   Sigara İçenlerin Ölüm Oranı
# 0                      % 8.94
# 1                      % 9.04
# 2                      % 9.11
# 3                      % 9.19
# 4                      % 9.27

# %%
# Sigara İçenlerin Ölüm Oranı - Toplam Ölen Kişi Sayısı Scatter Grafiği
plt.scatter(sigara_verisi["Toplam Ölen Kişi Sayısı (milyon)"], sigara_verisi["Sigara İçenlerin Ölüm Oranı"], color="purple")
plt.xlabel('Toplam Ölen Kişi Sayısı (milyon)')
plt.ylabel('Sigara İçenlerin Ölüm Oranı')
plt.title('Sigara İçenlerin Ölüm Oranı - Toplam Ölen Kişi Sayısı')
plt.show()

# %%
# Modelleme için veriyi hazırlama

#sci-kit learn kütüphanesini import edelim
from sklearn.linear_model import LinearRegression

#linear regression modelini oluşturalım
model = LinearRegression()

sigara_verisi['Sigara İçenlerin Ölüm Oranı'] = sigara_verisi['Sigara İçenlerin Ölüm Oranı'].replace({'%': '', ',': ''}, regex=True).astype(float)

# modelinizi eğitelim
# x değişkenimiz Sigara İçenlerin Ölüm Oranı, y değişkenimiz Toplam Ölen Kişi Sayısı (milyon)

model.fit(sigara_verisi[["Sigara İçenlerin Ölüm Oranı"]],sigara_verisi["Toplam Ölen Kişi Sayısı (milyon)"])
# Out:
# LinearRegression()

# %%
# Tahmin edilen değerleri alalım
tahmin_edilen_degerler = model.predict(sigara_verisi[["Sigara İçenlerin Ölüm Oranı"]])
tahmin_edilen_degerler
# Out:
# array([58.83555984, 58.8670585 , 58.88910757, 58.9143065 , 58.93950542,
#        58.91115663, 58.93635556, 58.95840462, 58.98360355, 59.00565261,
#        59.23244297, 59.2576419 , 59.27024136, 59.30174002, 59.33008882,
#        59.86241619, 59.39938587, 59.86241619, 59.86241619, 60.10810574,
#        60.149054  , 60.36009503, 60.3632449 ])

# %%
# Modeli görselleştirme
plt.scatter(sigara_verisi["Sigara İçenlerin Ölüm Oranı"], sigara_verisi["Toplam Ölen Kişi Sayısı (milyon)"], color = "green")
plt.plot(sigara_verisi["Sigara İçenlerin Ölüm Oranı"], tahmin_edilen_degerler, color = "blue")
plt.xlabel("Sigara İçenlerin Ölüm Oranı")
plt.ylabel("Toplam Ölen Kişi Sayısı (milyon)")
plt.title("Sigara İçenlerin Ölüm Oranı - Toplam Ölen Kişi Sayısı (milyon) Grafiği")
plt.show()
